# %% [markdown]
# # [Classification task] - Titanic dataset

# %% [markdown]
# This project is about the Titanic disaster of 1912. The main goal of this notebook is to try to present a complete approach to modeling problems, that goes from Exploratory Data Analysis to applying Supervised learning techniques to our data. This notebook's content is mainly directed to data scientists, data science students or people interested in how these techniques can be applied into data.

# %% [markdown]
# ![St%C3%B6wer_Titanic.jpg](attachment:St%C3%B6wer_Titanic.jpg)

# %% [markdown]
# The Titanic was launched on May 31, 1911. As it prepared to embark on its maiden voyage, the Titanic was one of the largest and most opulent ships in the world. It had a gross registered tonnage (i.e., carrying capacity) of 46,328 tons, and when fully laden the ship displaced (weighed) more than 52,000 tons. The Titanic was approximately 882.5 feet (269 metres) long and about 92.5 feet (28.2 metres) wide at its widest point. Titanic was 882 feet 9 inches (269.06 m) long with a maximum breadth of 92 feet 6 inches (28.19 m). Titanic total height, measured from the base of the keel to the top of the bridge, was 104 feet (32 m). She measured 46,329 GRT and 21,831 NRT and with a draught of 34 feet 7 inches (10.54 m), she displaced 52,310 tons. All three of the Olympic-class ships had ten decks (excluding the top of the officers' quarters), eight of which were for passenger use. From top to bottom, the decks were:
#
# The Boat Deck, on which the lifeboats were housed. It was from here during the early hours of 15 April 1912 that Titanic's lifeboats were lowered into the North Atlantic. The bridge and wheelhouse were at the forward end, in front of the captain's and officers' quarters. The bridge stood 8 feet (2.4 m) above the deck, extending out to either side so that the ship could be controlled while docking. The wheelhouse stood within the bridge. The entrance to the First Class Grand Staircase and gymnasium were located midships along with the raised roof of the First Class lounge, while at the rear of the deck were the roof of the First Class smoke room and the relatively modest Second Class entrance. The wood-covered deck was divided into four segregated promenades: for officers, First Class passengers, engineers, and Second Class passengers respectively. Lifeboats lined the side of the deck except in the First Class area, where there was a gap so that the view would not be spoiled.
#
# Source: Wikipedia & Britannica (https://en.wikipedia.org/wiki/Titanic)/(https://www.britannica.com/topic/Titanic)

# %% [markdown]
# ## Information about dataset

# %% [markdown]
# Titanic Data - Contains demographics and passenger information from 891 of the 2224 passengers and crew on board the Titanic. The Titanic data containsa mix of textual, Boolean, continuous, and categorical variables. It exhibits interesting characteristics such as missing values, outliers, and text variables ripe for text mining–a rich database that will allow us to demonstrate data transformations. We will use the classic Titanic dataset. The dataconsists of demographic and traveling information for1,309 of the Titanic passengers, and the goal isto predict the survival of these passengers.  The Titanic datasetis also the subject of the introductory competition on Kaggle.com
#
# We have 1,309 records and 14 attributes, three of which we will discard. The home.dest attribute hastoo few existing values, the boat attribute is only present for passengers who have survived, and thebody attributeis only for passengers who have not survived. We will discard these three columnslater on while using the data schema.

# %% [markdown]
# ## Dataset Attribution

# %% [markdown]
# Features
# After getting a better perception of the different aspects of the dataset, I started exploring the features and the part they played in the survival or demise of a traveler.
#
# - Survived -
# the first feature reported if a traveler lived or died. A comparison revealed that more than 60% of the passengers had died.
#
# - Pclass -
# this feature renders the passenger division. The tourists could opt from three distinct sections, namely class-1, class-2, class-3. The third class had the highest number of commuters, followed by class-2 and class-1. The number of tourists in the third class was more than the number of passengers in the first and second class combined. The survival chances of a class-1 traveler were higher than a class-2 and class-3 traveler.
#
# - Sex -
# approximately 65% of the tourists were male while the remaining 35% were female. Nonetheless, the percentage of female survivors was higher than the number of male survivors. More than 80% of male commuters died, as compared to around 70% female commuters.
#
# - Age -
# the youngest traveler onboard was aged around two months and the oldest traveler was 80 years. The average age of tourists onboard was just under 30 years. Clearly, a larger fraction of children under 10 survived than died. or every other age group, the number of casualties was higher than the number of survivors. More than 140 people within the age group 20 and 30 were dead as compared to just around 80 people of the same age range sustained.
#
# - SibSp-
# sibSp is the number of siblings or spouse of a person onboard. A maximum of 8 siblings and spouses traveled along with one of the traveler. More than 90% of people traveled alone or with one of their sibling or spouse. The chances of survival dropped drastically if someone traveled with more than 2 siblings or spouse.
#
# - Parch-
# similar to the SibSp, this feature contained the number of parents or children each passenger was touring with. A maximum of 9 parents/children traveled along with one of the traveler.
#
# - Pclass: A proxy for socio-economic status (SES)
# 1st = Upper
# 2nd = Middle
# 3rd = Lower
#
# - Fare -
# by splitting the fare amount into four categories, it was obvious that there was a strong association between the charge and the survival. The higher a tourist paid, the higher would be his chances to survive.
#
# - Embarked -
# embarked implies where the traveler mounted from. There are three possible values for Embark — Southampton, Cherbourg, and Queenstown. More than 70% of the people boarded from Southampton. Just under 20% boarded from Cherbourg and the rest boarded from Queenstown. People who boarded from Cherbourg had a higher chance of survival than people who boarded from Southampton or Queenstown.
#
# - Cabin -
# is the cabin number of the passenger

# %% [markdown]
# ### Study Objective

# %% [markdown]
# - Problem understanding and definition: understand the problem and how the potential solution would look. Also, define the requirements for solving the problem
# - Data collection and preparation: get a dataset that is ready for analysis
# - Data understanding using Exploratory Data Analysis (EDA): understand your dataset
# - Feature Engineering and Data Processing: process of using raw data to create features that will be used for predictive modeling.
# - Model building: produce some predictive models that solve the problem
# - Model evaluation: choose the best model among a subset of the most promising ones and determine how good the model is in providing the solution
# - Communication and/or deployment: use the predictive model and its results

# %% [markdown]
# ### Research process

# %% [markdown]
# - Worked 21 hours for 2 weeks as a data scientist and developed classification models that could predict survival rate among Titanic passangers predicted by study factors. Data Analysis included using different analysing techniques, fact-checking, extracting new data, patterns & data visualisation,feature engineering, building pipelines, tunning hiperparameters and final evaluation & reporting.

# %% [markdown]
# ## 1. Import libraries

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 

import scipy.stats as stats
from mlens.visualization import corrmat
import plotly.express as px


from sklearn.pipeline import Pipeline 
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler, Normalizer 
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split 

from feature_engine.encoding import MeanEncoder, DecisionTreeEncoder, OneHotEncoder, OrdinalEncoder, RareLabelEncoder, CountFrequencyEncoder 
from feature_engine.imputation import MeanMedianImputer, CategoricalImputer
from feature_engine.discretisation import EqualFrequencyDiscretiser, EqualWidthDiscretiser, DecisionTreeDiscretiser 
from feature_engine.imputation import AddMissingIndicator, MeanMedianImputer, CategoricalImputer, ArbitraryNumberImputer, RandomSampleImputer

from sklearn.metrics import (classification_report, 
                             confusion_matrix,
                             roc_auc_score,
                             accuracy_score,
                             precision_score, 
                             recall_score, 
                             f1_score)
from sklearn.metrics import plot_confusion_matrix 

from feature_engine.selection import DropConstantFeatures, DropDuplicateFeatures 
from feature_engine.selection import SmartCorrelatedSelection

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ## 2. Define functions

# %%
# Show in DataFrame missing values with type of variable

def missing_value_info(data):
    nan_list = [var for var in data.columns if data[var].isnull().sum() > 0]
    info_na = data[nan_list].isnull().mean().round(3).sort_values(ascending = False).reset_index()
    info_na.columns = ['Columns','Nan_mean']
    info_na['Type'] = info_na.Columns.map(data.dtypes)
    info_na.Type = np.where(info_na.Type == 'O','Categorical', info_na.Type)
    info_na.Type = np.where(info_na.Type != 'Categorical','Numerical', info_na.Type)

    return info_na

# Visualizing in plot missing values
def missing_value_info_plot(data):    
    info = missing_value_info(data)
    plt.figure(figsize=(len(info.Columns) * 1.5, 2.5))
    plt.plot(info.Nan_mean,'b.-')
    plt.axhline(y = 0.5,color = 'red')
    plt.yticks(np.arange(0, 1.2, 0.2))
    plt.xticks(info.Columns.index,info.Columns,rotation = 90)
    plt.ylabel('Percentage of missing data')
    plt.grid()
    
    plt.show()

# %%
# Visualizing histogram, probability plot and box-plot

def diagnostic_plots(data, variable):
    fig = plt.figure()
    plt.figure(figsize = (18, 5))
   
    # Histogram
    plt.subplot(1, 3, 1)
    fig = data[variable].hist(bins = 30)
    fig.set_ylabel ('Number of houses')
    fig.set_xlabel(variable)
    
    # Probability plot
    plt.subplot(1, 3, 2)
    stats.probplot(data[variable], dist = 'norm', plot = plt)
    
    # Box-plot
    plt.subplot(1, 3, 3)
    fig = data.boxplot(column = variable)
    fig.set_title('Box-plot')
    fig.set_ylabel(variable)
    
    plt.tight_layout()
    plt.show()

# %%
# Check multicollinearity
def multicollinearity(data, threshold):
    
    col_corr = set()
    
    corr_matrix = data.corr().round(3)
    
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold:
                print(abs(corr_matrix.iloc[i, j]), corr_matrix.columns[i], corr_matrix.columns[j])

# %% [markdown]
# ## 3.  Download dataset

# %%
# Download the dataset
data = pd.read_csv('../AI/titanic.csv')

# %% [markdown]
# ## 4. Exploratory data analysis (EDA)

# %%
# Checking dataset features
data.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375    B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500   C22        S   11    NaN
# 2   2.0000      1      2  113781  151.5500   C22        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500   C22        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500   C22        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
# Checking dataset features
data.tail()
# Out:
#       pclass  survived                       name     sex   age  sibsp  parch  \
# 1304       3         0       Zabour, Miss. Hileni  female  14.5      1      0
# 1305       3         0      Zabour, Miss. Thamine  female   NaN      1      0
# 1306       3         0  Zakarian, Mr. Mapriededer    male  26.5      0      0
# 1307       3         0        Zakarian, Mr. Ortin    male  27.0      0      0
# 1308       3         0         Zimmerman, Mr. Leo    male  29.0      0      0
#
#       ticket     fare cabin embarked boat   body home.dest
# 1304    2665  14.4542   NaN        C  NaN  328.0       NaN
# 1305    2665  14.4542   NaN        C  NaN    NaN       NaN
# 1306    2656   7.2250   NaN        C  NaN  304.0       NaN
# 1307    2670   7.2250   NaN        C  NaN    NaN       NaN
# 1308  315082   7.8750   NaN        S  NaN    NaN       NaN

# %%
# Define null labels 
data.isnull().mean()
# Out:
# pclass       0.000000
# survived     0.000000
# name         0.000000
# sex          0.000000
# age          0.200917
# sibsp        0.000000
# parch        0.000000
# ticket       0.000000
# fare         0.000764
# cabin        0.774637
# embarked     0.001528
# boat         0.628724
# body         0.907563
# home.dest    0.430863
# dtype: float64

# %%
# Define null labels 
data.isnull().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
# Define missing values 
missing_value_info(data)
# Out:
#      Columns  Nan_mean         Type
# 0       body     0.908    Numerical
# 1      cabin     0.775  Categorical
# 2       boat     0.629  Categorical
# 3  home.dest     0.431  Categorical
# 4        age     0.201    Numerical
# 5   embarked     0.002  Categorical
# 6       fare     0.001    Numerical

# %%
# Define missing values 
total = data.isnull().sum().sort_values(ascending=False)
percent = (data.isnull().sum()/data.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(20)
# Out:
#            Total   Percent
# body        1188  0.907563
# cabin       1014  0.774637
# boat         823  0.628724
# home.dest    564  0.430863
# age          263  0.200917
# embarked       2  0.001528
# fare           1  0.000764
# pclass         0  0.000000
# survived       0  0.000000
# name           0  0.000000
# sex            0  0.000000
# sibsp          0  0.000000
# parch          0  0.000000
# ticket         0  0.000000

# %%
# Define features type
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
# Checking basic background information including mean, std, min & max parameters 
data.describe().T.style.background_gradient(cmap = "cividis")
# Out:
# <style type="text/css">
# #T_653fb_row0_col0, #T_653fb_row0_col3, #T_653fb_row1_col0, #T_653fb_row3_col0, #T_653fb_row4_col0, #T_653fb_row5_col0, #T_653fb_row5_col7, #T_653fb_row6_col1, #T_653fb_row6_col2, #T_653fb_row6_col3, #T_653fb_row6_col4, #T_653fb_row6_col5, #T_653fb_row6_col6 {
#   background-color: #fee838;
#   color: #000000;
# }
# #T_653fb_row0_col1, #T_653fb_row0_col6, #T_653fb_row3_col7 {
#   background-color: #002553;
#   color: #f1f1f1;
# }
# #T_653fb_row0_col2, #T_653fb_row1_col1, #T_653fb_row1_col2, #T_653fb_row1_col3, #T_653fb_row1_col4, #T_653fb_row1_col5, #T_653fb_row1_col7, #T_653fb_row3_col1, #T_653fb_row3_col3, #T_653fb_row3_col4, #T_653fb_row3_col5, #T_653fb_row4_col1, #T_653fb_row4_col2, #T_653fb_row4_col3, #T_653fb_row4_col4, #T_653fb_row4_col5, #T_653fb_row4_col6, #T_653fb_row5_col3, #T_653fb_row6_col0 {
#   background-color: #00224e;
#   color: #f1f1f1;
# }
# #T_653fb_row0_col4 {
#   background-color: #002859;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# - From this function we could see that among passengers were infants less than 1 year old and the oldest passenger was in his/her 80th, the mean age value is defined as 29 years old.

# %% [markdown]
# ### 4.1. Define study variables

# %%
# Define categorical variables
categorical = [var for var in data.columns if data [var].dtype == 'O']
print('There are {} categorical variables'.format(len(categorical)))

# Define numerical variables
numerical = [var for var in data.columns if data[var].dtype !='O']
print('There are {} numerical variables'.format(len(numerical)))
# Out:
# There are 7 categorical variables
# There are 7 numerical variables

# %%
# Print categorical variables
print(data.select_dtypes(include = ['object']).columns.values)
# Out:
# ['name' 'sex' 'ticket' 'cabin' 'embarked' 'boat' 'home.dest']

# %%
# Print numerical variables
print(data.select_dtypes(include = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']).columns.values)
# Out:
# ['pclass' 'survived' 'age' 'sibsp' 'parch' 'fare' 'body']

# %% [markdown]
# #### Conclusion:
# - The Training dataset has information about 1309 passengers of the Titanic disaster. We have 13 independent variables including 7 categorical variables, 6 numerical variables and one dependent variable which is our target. Features type are float64(3), int64(4), object(7).
#
# - This dataset contains missing values, 4 features ('body', 'cabin', 'boat', 'home.dest') have more than 43% of missing values, one feature ('age') has 20% of missing values and 2 variables ('embarked','fare') have less than 1% of missing values.

# %% [markdown]
# ### 4.2. Define cardinality in studying variables

# %%
# Define unique labels numbers in the study features
data.nunique()
# Out:
# pclass          3
# survived        2
# name         1307
# sex             2
# age            98
# sibsp           7
# parch           8
# ticket        929
# fare          281
# cabin         181
# embarked        3
# boat           27
# body          121
# home.dest     369
# dtype: int64

# %%
# Define unique labels in the age feature
data['age'].unique()
# Out:
# array([29.    ,  0.9167,  2.    , 30.    , 25.    , 48.    , 63.    ,
#        39.    , 53.    , 71.    , 47.    , 18.    , 24.    , 26.    ,
#        80.    ,     nan, 50.    , 32.    , 36.    , 37.    , 42.    ,
#        19.    , 35.    , 28.    , 45.    , 40.    , 58.    , 22.    ,
#        41.    , 44.    , 59.    , 60.    , 33.    , 17.    , 11.    ,
#        14.    , 49.    , 76.    , 46.    , 27.    , 64.    , 55.    ,
#        70.    , 38.    , 51.    , 31.    ,  4.    , 54.    , 23.    ,
#        43.    , 52.    , 16.    , 32.5   , 21.    , 15.    , 65.    ,
#        28.5   , 45.5   , 56.    , 13.    , 61.    , 34.    ,  6.    ,
#        57.    , 62.    , 67.    ,  1.    , 12.    , 20.    ,  0.8333,
#         8.    ,  0.6667,  7.    ,  3.    , 36.5   , 18.5   ,  5.    ,
#        66.    ,  9.    ,  0.75  , 70.5   , 22.5   ,  0.3333,  0.1667,
#        40.5   , 10.    , 23.5   , 34.5   , 20.5   , 30.5   , 55.5   ,
# ...

# %%
# Define cardinality in the age feature
plt.figure(figsize=(20,10))
data['age'].value_counts().sort_values(ascending = False).plot.bar() #отсортируй по убывающей
plt.xlabel('age')
plt.ylabel('Age range among passangers')
# Out:
# Text(0, 0.5, 'Age range among passangers')

# %%
# Define unique labels numbers in the study features
data['boat'].unique()
# Out:
# array(['2', '11', nan, '3', '10', 'D', '4', '9', '6', 'B', '8', 'A', '5',
#        '7', 'C', '14', '5 9', '13', '1', '15', '5 7', '8 10', '12', '16',
#        '13 15 B', 'C D', '15 16', '13 15'], dtype=object)

# %%
# Define cardinality in the boat feature
plt.figure(figsize=(20,10))
data['boat'].value_counts().sort_values(ascending = False).plot.bar()
plt.xlabel('boat')
plt.ylabel('Number of boat')
sns.set_theme(style="whitegrid")

# %% [markdown]
# #### Conclusion:
# - This dataset features' contain a lot of labels that might bring to the multicollinearity problem. Some variables like 'age' also consist a lot of missing nan data, that we have to deal with, another variables like 'boat' has mixed labels both numerical and categorical.

# %% [markdown]
# ### 4.3. Define values distribution & define outliers

# %%
# Define values distribution & define outliers
for var in data[numerical]:
    diagnostic_plots(data[numerical], var)

# %%
# Define median age defined by passengers class 
print('Median for age seperated by pclass:')
display(data.groupby('pclass')['age'].median())
print('Median for age seperated by pclass and sex: ')
display(data.groupby(['pclass', 'sex'])['age'].median())
print('Number of cases: ')
display(data.groupby(['pclass', 'sex'])['age'].count())
# Out:
# Median for age seperated by pclass:
# pclass
# 1    39.0
# 2    29.0
# 3    24.0
# Name: age, dtype: float64
# Median for age seperated by pclass and sex:
# pclass  sex
# 1       female    36.0
#         male      42.0
# 2       female    28.0
#         male      29.5
# 3       female    22.0
#         male      25.0
# Name: age, dtype: float64
# Number of cases:
# pclass  sex
# 1       female    133
#         male      151
# 2       female    103
#         male      158
# 3       female    152
#         male      349
# Name: age, dtype: int64

# %% [markdown]
# #### Conclusion:
# - From analysis in features ('name', 'age', 'ticket', 'fare', 'cabin', 'body', 'home.dest'), I found that they have a very high amount of multicollinearity. It can lead to the problem of dealing with rare labels in the training part and cause model overfitting. Let's leave it as it is for now and keep in mind that we have to deal with these features in the feature engineering. Some of these features could be removed from the dataset because they have a lot of missing values like 'body' 90%, 'home.dest' 43%  features that probably does not predict very much survival rate among titanic passengers.
#
# - Though other features like 'age' that are missing 20% of its values are pretty important to survive, so we would better try to fill these gaps. I found that male in the first class were almost twice older than their counterparts from the 2nd and 3d classes, 42 years and 29, 25 years respectively. Same pattern with less age gap we can witness among female passengers 36 years, 28 and 22 years respectively. By this we can conclude that first class passengers were more older whereas second and third class passengers were younger. Finally, I found that while in the first class the number of males to females were slightly higher 151 to 133, this number increased based on class second class females 103, males 158, third class females 152, males 349.

# %% [markdown]
# ## 5. Feature Analysis

# %% [markdown]
# ### 5.1. Gender feature

# %%
# Define survival rate among passangers
f,ax=plt.subplots(1,2,figsize=(18,8),)
data['survived'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('survived')
ax[0].set_ylabel('')
sns.countplot('survived',data=data,ax=ax[1], palette="OrRd")
ax[1].set_title('survived')
plt.show()
# Out:
# C:\Users\kmk\anaconda3\envs\AI\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
#  - This bar plot above shows the distribution of passangers survived. Most of the passangers died out of 1309 passngers only 500 passangers could survive.

# %%
# Define survival rate among passangers based on gender
f,ax=plt.subplots(1,2,figsize=(18,8))
data[['sex','survived']].groupby(['sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')
sns.countplot('sex',hue='survived',data=data,ax=ax[1])
ax[1].set_title('Survived vs Dead predicted by gender')
plt.show()
# Out:
# C:\Users\kmk\anaconda3\envs\AI\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# - This bar plot above shows the distribution of female and male survived. This bar plot shows that ~74% female passenger survived while only ~19% male passenger survived. The number of men on the ship is lot more than the number of women. Still the number of women saved is almost twice the number of males saved.

# %%
# Define exact number of passangers who survived and who died 
print('Total dead people: ', data[data['survived'] == 0]['survived'].count())
print('Total survived people: ', data[data['survived'] == 1]['survived'].count())
# Out:
# Total dead people:  809
# Total survived people:  500

# %%
# define in % survival rate sort by gender 
data[['sex', 'survived']].groupby(['sex'], as_index=False).mean().sort_values(by='survived', ascending=False)
# Out:
#       sex  survived
# 0  female  0.727468
# 1    male  0.190985

# %%
# Define survival rate based on gender and the passangers class
sns.catplot(x = 'sex', y = 'survived', data = data, kind = 'bar', col = 'pclass')
plt.show()

# %% [markdown]
# - This bar plot above shows the distribution of female and male survived predicted by the class. This bar plot shows that first class passengers showed higher rate of survival 61% of passengers survived while from the second class 42% of passengers survived. The lowest number of survival was among passangers from the third class with only 25%, keep in mind that most of the passangers based on the third class (501 passangers in total).

# %%
# define in % survival rate sort by passangers' class 
data[['pclass', 'survived']].groupby(['pclass'], as_index=False).mean().sort_values(by='survived', ascending=False)
# Out:
#    pclass  survived
# 0       1  0.619195
# 1       2  0.429603
# 2       3  0.255289

# %% [markdown]
# #### Conclusion:
#
# - I found that only 38,2%  passengers survived (809 passengers died, 500 passengers survived). As you could see most of the survivors were females 72% and less male 19%. Another interesting finding was that first class passengers showed a higher rate of survival 61% compared to second class where only 42% of passengers survived and the third class with 25%.

# %% [markdown]
# ### 5.2. SibSp feature

# %%
# Define survival rate predicted by the distribution of siblings or spouses
plt.subplots(figsize=(20,8))
sns.barplot('sibsp','survived',data=data)
plt.title('Sibsp vs Survived')
# Out:
# C:\Users\kmk\anaconda3\envs\AI\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Sibsp vs Survived')

# %%
# Define survival rate predicted by the distribution of siblings or spouses
sns.catplot(x = 'sibsp', y = 'survived', kind = 'point', hue = 'sex', data = data, height = 6, aspect = 2)
plt.show()

# %% [markdown]
# - This bar plot above shows the distribution of siblings or spouse of a person onboard survived predicted by the family size. A maximum of 8 siblings and spouses traveled along with one of the traveler. More than 90% of people traveled alone or with one of their sibling or spouse. The chances of survival dropped drastically if someone traveled with more than 2 siblings or spouse.

# %%
# Define survival rate predicted by the distribution of siblings or spouses and gender
sns.catplot(x = 'sibsp', y = 'survived', kind = 'bar', hue = 'sex', data = data, height = 6, aspect = 2)
plt.show()

# %% [markdown]
# - This bar plot above shows the distribution of siblings or spouse of a person onboard survived predicted by the family size and the gender. A maximum of 8 siblings and spouses traveled along with one of the traveler. More than 90% of people traveled alone or with one of their sibling or spouse. The chances of survival dropped drastically if someone traveled with more than 2 siblings or spouse.

# %%
# Define survival rate predicted by the distribution of siblings or spouses and their class
sns.catplot(x = 'sibsp', y = 'survived', col = 'pclass', kind = 'bar', data = data)
plt.show()

# %%
# Define survival rate predicted by the distribution of siblings or spouses
data[['sibsp', 'survived']].groupby(['sibsp'], as_index=False).mean().sort_values(by='survived', ascending=False)
# Out:
#    sibsp  survived
# 1      1  0.510972
# 2      2  0.452381
# 0      0  0.346801
# 3      3  0.300000
# 4      4  0.136364
# 5      5  0.000000
# 6      8  0.000000

# %% [markdown]
# - This bar plot above shows the distribution of siblings or spouse of a person on board survived predicted by the size and the class. Interestingly, passengers from the second class with 3 siblings or spouses showed a higher rate of survival compared to the passengers from the 1st class.

# %% [markdown]
# ### 5.3. Parch feature

# %%
# Define survival rate predicted by the distribution of of parents/children on board
plt.subplots(figsize=(20,8))
sns.barplot('parch','survived',data=data)
plt.title('Parch vs Survived')
# Out:
# C:\Users\kmk\anaconda3\envs\AI\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Parch vs Survived')

# %% [markdown]
# - This bar plot above shows the distribution of parents/children on board survived predicted by the size. Parch- similar to the SibSp, this feature contained the number of parents or children each passenger was touring with. A maximum of 9 parents/children traveled along with one of the traveler. Similar to SibSp we can see that more chances to survive had those passangers that travelled either alone or in group with 3 person.

# %%
# Define survival rate predicted by the distribution of of parents/children on board and their gender
sns.catplot(x = 'parch', y = 'survived', data = data, hue = 'sex', kind = 'bar', height = 6, aspect = 2)
plt.show()

# %% [markdown]
# - This bar plot above shows the distribution of parents/children on board survived predicted by the gender. According to this graph we could conclude that more chances to survive had female passangers that travelled aither alone or in group with 3 person.

# %%
# Define survival rate predicted by the distribution of of parents/children on board
data[['parch', 'survived']].groupby(['parch'], as_index=False).mean().sort_values(by='survived', ascending=False)
# Out:
#    parch  survived
# 3      3  0.625000
# 1      1  0.588235
# 2      2  0.504425
# 0      0  0.335329
# 4      4  0.166667
# 5      5  0.166667
# 6      6  0.000000
# 7      9  0.000000

# %% [markdown]
# ### 5.4. Embarked feature

# %%
# Define survival rate predicted by the embarked feature
plt.figure(figsize = (20, 6))
sns.countplot('embarked', hue = 'survived', data = data)
plt.show()
# Out:
# C:\Users\kmk\anaconda3\envs\AI\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Define survival rate predicted by the embarked feature and gender
sns.catplot(x = 'embarked', y = 'survived', kind = 'bar', data = data, col = 'sex', height=4, aspect=2)
plt.show()

# %% [markdown]
# - Embarked implies where the traveler mounted from. There are three possible values for Embark — Southampton, Cherbourg, and Queenstown. More than 70% of the people boarded from Southampton. Just under 20% boarded from Cherbourg and the rest boarded from Queenstown. People who boarded from Cherbourg had a higher chance of survival than people who boarded from Southampton or Queenstown.

# %%
# Define survival rate predicted by the embarked feature, gender and class
f,ax=plt.subplots(2,2,figsize=(20,15))
sns.countplot('embarked',data=data,ax=ax[0,0], palette="OrRd")
ax[0,0].set_title('No. Of Passengers Boarded')
sns.countplot('embarked',hue='sex',data=data,ax=ax[0,1], palette="OrRd")
ax[0,1].set_title('Male-Female Split for Embarked')
sns.countplot('embarked',hue='survived',data=data,ax=ax[1,0], palette="OrRd")
ax[1,0].set_title('Embarked vs Survived')
sns.countplot('embarked',hue='pclass',data=data,ax=ax[1,1], palette="OrRd")
ax[1,1].set_title('Embarked vs Pclass')
plt.subplots_adjust(wspace=0.2,hspace=0.5)
plt.show()
# Out:
# C:\Users\kmk\anaconda3\envs\AI\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\kmk\anaconda3\envs\AI\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\kmk\anaconda3\envs\AI\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# - The proportion of first class passengers is higher for those who came from Cherbourg than Queenstown (Q), Southampton (S). the third class is the most frequent for passenger coming from Southampton (S) and Queenstown (Q), whereas Cherbourg passengers are mostly in first class which have the highest survival rate and the first class passengers were prioritised during the evacuation due to their influence.

# %%
#now we need to fill in the missing values in the Embarked feature
print("Number of people embarking in Southampton (S):")
southampton = data[data["embarked"] == "S"].shape[0]
print(southampton)

print("Number of people embarking in Cherbourg (C):")
cherbourg = data[data["embarked"] == "C"].shape[0]
print(cherbourg)

print("Number of people embarking in Queenstown (Q):")
queenstown = data[data["embarked"] == "Q"].shape[0]
print(queenstown)
# Out:
# Number of people embarking in Southampton (S):
# 914
# Number of people embarking in Cherbourg (C):
# 270
# Number of people embarking in Queenstown (Q):
# 123

# %% [markdown]
# ### #Fact - checking
#
# - Over 500 households in Southampton lost at least one family member in the Titanic disaster. Titanic remained docked in Southampton for a week before welcoming passengers and crew aboard on April 10 and setting out to sea at noon that day. From Southampton, Titanic docked in Cherbourg, France and finally Queenstown, now Cobh, in Co Cork in Ireland before heading for New York City. At Southampton, 920 people boarded Titanic with more than half being third-class passengers: 179 were First Class, 247 Second Class, and 494 Third Class. Of the 908 crew members aboard Titanic, 724 were from Southampton. Of the 685 crew members who perished when Titanic sank, 549 were from Southampton.
# - Source: (Britishheritage) https://britishheritage.com/history/titanic-southampton

# %% [markdown]
# ### 5.5. Cabin feature

# %%
# Redefine cabin feature excluding numerical labels 
data['cabin'] = data['cabin'].str[0]
data.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375     B        S    2    NaN
# 1   0.9167      1      2  113781  151.5500     C        S   11    NaN
# 2   2.0000      1      2  113781  151.5500     C        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500     C        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500     C        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
# Define survival rate predicted by the cabin type 
data[['cabin', 'survived']].groupby('cabin')['survived'].mean().plot(kind = 'bar', figsize = (20, 7))
plt.suptitle('Survival rate based on cabin class', fontsize = 20)
# Out:
# Text(0.5, 0.98, 'Survival rate based on cabin class')

# %% [markdown]
# - Cabin - is the cabin number of the passenger. I tried to group this feature with the survival rate and from this graph we see that cabin is not significantly predicts survival rate among passangers.

# %%
# Define number of passangers in each cabin type 
plt.figure(figsize=(20,7))
data['cabin'].value_counts().sort_values(ascending = False).plot.bar()
plt.xlabel('cabin')
plt.ylabel('Number of PASSENGERS in cabins')
# Out:
# Text(0, 0.5, 'Number of PASSENGERS in cabins')

# %% [markdown]
# - On the Boat Deck there were 6 rooms labeled as T, U, W, X, Y, Z but only the T cabin is present in the dataset A, B and C decks were only for 1st class passengers D and E decks were for all classes F and G decks were for both 2nd and 3rd class passengers. From going A to G, distance to the staircase increases which might be a factor of survival

# %% [markdown]
# ### 5.6. Pclass feature

# %%
# Define survival rate predicted by the passangers class
values = data['pclass'].value_counts()
labels = ['Third Class', 'Second Class', 'First Class']
explode = (0, 0, 0.08)

fig, ax = plt.subplots(figsize = (5, 6), dpi = 100)
patches, texts, autotexts = ax.pie(values, labels = labels, autopct = '%1.2f%%', shadow = True,
                                   startangle = 90, explode = explode)

plt.setp(texts, color = 'grey')
plt.setp(autotexts, size = 13, color = 'white')
autotexts[2].set_color('black')
plt.show()

# %%
# Define survival rate predicted by the passangers class
data[['pclass','survived']].groupby('pclass')['survived'].mean().plot(kind = 'bar', figsize = (20, 7))
plt.suptitle('Survival rate based on pclass', fontsize = 20)
# Out:
# Text(0.5, 0.98, 'Survival rate based on pclass')

# %%
# Define survival rate predicted by the passangers' class
# Kernel Density Plot
fig = plt.figure(figsize=(15,8),) 
ax=sns.kdeplot(data.pclass[data.survived == 0] , 
               color='gray',
               shade=True,
               label='not survived')
ax=sns.kdeplot(data.loc[(data['survived'] == 1),'pclass'] , 
               color='g',
               shade=True, 
               label='survived', 
              )
plt.title('Passenger Class Distribution - Survived vs Non-Survived', fontsize = 25, pad = 40)
plt.xlabel("Passenger Class", fontsize = 15,labelpad =20)
plt.ylabel("Frequency of Passenger Survived", fontsize = 15, labelpad = 20)
## Converting xticks into words for better understanding
labels = ['Upper', 'Middle', 'Lower']
plt.xticks(sorted(data.pclass.unique()), labels);

# %% [markdown]
# - It looks like first class passenger survived titanic tragedy, then second class and the last third class passenger survived. This KDE plot is pretty self-explanatory with all the labels and colors. Something I have noticed that some readers might find questionable is that the lower class passengers have survived more than second-class passengers. It is true since there were a lot more third-class passengers than first and second. The first class passengers had the upper hand during the tragedy.

# %% [markdown]
# ### 5.7. Fare feature

# %%
# Define survival rate predicted by the passangers' fare
# Kernel Density Plot
fig = plt.figure(figsize=(15,8),)
ax=sns.kdeplot(data.loc[(data['survived'] == 0),'fare'] , color='gray',shade=True,label='not survived')
ax=sns.kdeplot(data.loc[(data['survived'] == 1),'fare'] , color='g',shade=True, label='survived')
plt.title('Fare Distribution Survived vs Non Survived', fontsize = 25, pad = 40)
plt.ylabel("Frequency of Passenger Survived", fontsize = 15, labelpad = 20)
plt.xlabel("Fare", fontsize = 15, labelpad = 20);

# %% [markdown]
# - The spike in the plot under 100 dollar represents that a lot of passengers who bought the ticket within that range did not survive. When fare is approximately more than 280 dollars, there is no gray shade which means, either everyone passed that fare point survived or maybe there is an outlier that clouds our judgment.

# %% [markdown]
# ### 5.8. Age feature

# %%
# Peaks for survived/not survived passengers by their age
facet = sns.FacetGrid(data, hue="survived",aspect=4)
facet.map(sns.kdeplot,'age',shade= True)
facet.set(xlim=(0, data['age'].max()))
facet.add_legend()

# %%
# Peaks for survived/not survived passengers by their age
# Kernel Density Plot
fig = plt.figure(figsize=(15,8),)
ax=sns.kdeplot(data.loc[(data['survived'] == 0),'age'] , color='gray',shade=True,label='not survived')
ax=sns.kdeplot(data.loc[(data['survived'] == 1),'age'] , color='g',shade=True, label='survived')
plt.title('Age Distribution - Surviver V.S. Non Survivors', fontsize = 25, pad = 40)
plt.xlabel("Age", fontsize = 15, labelpad = 20)
plt.ylabel('Frequency', fontsize = 15, labelpad= 20);

# %%
# Define how age affected to the survival rate mediated by study features
g = sns.factorplot(y="age",x="sex", hue="survived", data=data,kind="box", palette="OrRd", size=6, aspect=2)
g = sns.factorplot(y="age",x="pclass",hue="survived", data=data,kind="box", palette="OrRd", size=6, aspect=2)
g = sns.factorplot(y="age",x="parch", hue="survived", data=data,kind="box", palette="OrRd", size=6, aspect=2)
g = sns.factorplot(y="age",x="sibsp", hue="survived", data=data,kind="box", palette="OrRd", size=6, aspect=2)
g = sns.factorplot(y="age",x="fare", hue="survived", data=data,kind="box", palette="OrRd", size=6, aspect=2)
g = sns.factorplot(y="age",x="cabin", hue="survived", data=data,kind="box", palette="OrRd", size=6, aspect=2)
g = sns.factorplot(y="age",x="embarked", hue="survived", data=data,kind="box", palette="OrRd", size=6, aspect=2)
# Out:
# C:\Users\kmk\anaconda3\envs\AI\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\kmk\anaconda3\envs\AI\lib\site-packages\seaborn\categorical.py:3723: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\kmk\anaconda3\envs\AI\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# ...

# %% [markdown]
# - 1rst class passengers are older than 2nd class passengers who are also older than 3rd class passengers. Here I used an age feature to compare how it affected the survival rate mediated by the other study factors. We can summarize that high-class passengers showed the greater percentage of the survival rate though they were older than passengers from the 2nd and the 3rd classes. As we suspected, female passengers have survived at a much better rate than male passengers. It seems about right since females and children were the priority.
# - The average age of the passengers was about 30 years old, and according to the positive skewness of the histogram, they were generally young. Most passengers have bought cheap tickets. About 90% of passengers either did not have a family member with them or had at most 1 family member with them. Since most of the ‍‍Cabin data is missing in both training and test datasets, this feature will not bring much information to the model and its imputation will bring a lot of noise. Therefore, we remove Cabin from both datasets.

# %%
age_by_pclass_sex = data.groupby(['sex', 'pclass']).median()['age']

for pclass in range(1, 4):
    for sex in ['female', 'male']:
        print('Median age of Pclass {} {}s: {}'.format(pclass, sex, age_by_pclass_sex[sex][pclass]))
print('Median age of all passengers: {}'.format(data['age'].median()))

# Filling the missing values in Age with the medians of Sex and Pclass groups
data['age'] = data.groupby(['sex', 'pclass'])['age'].apply(lambda x: x.fillna(x.median()))
# Out:
# Median age of Pclass 1 females: 36.0
# Median age of Pclass 1 males: 42.0
# Median age of Pclass 2 females: 28.0
# Median age of Pclass 2 males: 29.5
# Median age of Pclass 3 females: 22.0
# Median age of Pclass 3 males: 25.0
# Median age of all passengers: 28.0

# %% [markdown]
# - In order to be more accurate, Sex feature is used as the second level of groupby while filling the missing Age values. As seen from below, Pclass and Sex groups have distinct median Age values. When passenger class increases, the median age for both males and females also increases. However, females tend to have slightly lower median Age than males. The median ages below are used for filling the missing values in Age feature.

# %% [markdown]
# ### 5.9. Features correlation Matrix

# %%
# Defining correlation between study variables 
corrmat(data.corr(), inflate=False, figsize=(18, 15))
plt.show()

# %% [markdown]
# - There is a mediated positive correlation between Fare and Survived rated. This relationship reveals that the passenger who paid more money for their ticket were more likely to survive. This theory aligns with one other correlation which is the correlation between Fare and Pclass(-0.56). This relationship can be explained by saying that first class passengers paid more for fare than second class passengers, similarly second class passenger paid more than the third class passengers. This theory can also be supported by mentioning another pclass correlation with our dependent variable, Survived. The correlation between Pclass and Survived is -0.31. This can also be explained by saying that first class passenger had a better chance of surviving than the second or the third and so on.

# %% [markdown]
# ## 6. Feature Engineering

# %% [markdown]
# ### 6.1. Features 'Parch' and 'Sibsp'

# %% [markdown]
# - Passenger who traveled in big groups with parents/children had less survival rate than other passengers. While, passenger who traveled in small groups with sibilings/spouses had better changes of survivint than other passengers. We can imagine that large families will have more difficulties to evacuate, looking for theirs sisters/brothers/parents during the evacuation. So, i choosed to create a "family_size" feature which is the sum of SibSp , Parch and 1 (including the passenger).

# %%
# Merge two study variables 'parch' and 'sibsp'
data['family_size'] = data['parch'] + data['sibsp']

# %%
# Define survival rate predicted by new merged variable 'family_size'
data[['family_size', 'survived']].groupby('family_size')['survived'].mean().plot(kind = 'bar', figsize = (20, 7))
plt.suptitle('Survival rate based on family size', fontsize = 20)
# Out:
# Text(0.5, 0.98, 'Survival rate based on family size')

# %% [markdown]
# - The family size seems to play an important role, survival probability is worst for large families. Additionally, i decided to created 4 categories of family size. This plot of family size category shows that Small and Medium families have more chance to survive than single passenger and large families.

# %% [markdown]
# ### 6.2. Feature 'Name'

# %%
# Define 'name' variable
data["name"].head(10)
# Out:
# 0                      Allen, Miss. Elisabeth Walton
# 1                     Allison, Master. Hudson Trevor
# 2                       Allison, Miss. Helen Loraine
# 3               Allison, Mr. Hudson Joshua Creighton
# 4    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5                                Anderson, Mr. Harry
# 6                  Andrews, Miss. Kornelia Theodosia
# 7                             Andrews, Mr. Thomas Jr
# 8      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9                            Artagaveytia, Mr. Ramon
# Name: name, dtype: object

# %% [markdown]
# - The Name feature contains information on passenger's title. Since some passenger with distingused title may be preferred during the evacuation, it is interesting to add them to the model.

# %%
# Get titles from 'name' variable
dataset_title = [i.split(",")[1].split(".")[0].strip() for i in data["name"]]
data["title"] = pd.Series(dataset_title)
data['title'].value_counts()
# Out:
# Mr              757
# Miss            260
# Mrs             197
# Master           61
# Rev               8
# Dr                8
# Col               4
# Mlle              2
# Ms                2
# Major             2
# Capt              1
# Sir               1
# Dona              1
# Jonkheer          1
# the Countess      1
# Don               1
# Mme               1
# Lady              1
# Name: title, dtype: int64

# %% [markdown]
# There is 17 titles in the dataset, most of them are very rare and we can group them in 4 categories

# %%
# Get titles from 'name' variable
plt.figure(figsize=(20,10))
title = sns.countplot(x="title",data=data, palette="OrRd")
title = plt.setp(title.get_xticklabels(), rotation=45)

# %% [markdown]
# - Title is created by extracting the prefix before Name feature. According to graph below, there are many titles that are occuring very few times. Some of those titles doesn't seem correct and they need to be replaced. Miss, Mrs, Ms, Mlle, Lady, Mme, the Countess, Dona titles are replaced with Miss/Mrs/Ms because all of them are female. Values like Mlle, Mme and Dona are actually the name of the passengers, but they are classified as titles because Name feature is split by comma. Dr, Col, Major, Jonkheer, Capt, Sir, Don and Rev titles are replaced with Dr/Military/Noble/Clergy because those passengers have similar characteristics. Master is a unique title. It has the highest survival rate among all males.
# - Mrs title has the highest survival rate among other female titles. This title needs to be a feature because all female titles are grouped with each other.

# %%
# Replace titles from 'name' variable
data['title'] = data['title'].replace(['Rev', 'Dr','Col', 'Mlle', 'Major', 
                                       'Capt', 'Sir', 'Dona', 'Jonkheer',
                                       'the Countess', 'Don', 'Mme', 'Lady'], 'Rare')
data['title'] = data['title'].replace(['Miss', 'Ms'], 'Miss')

# %%
# Define new titles from 'name variable'
plt.figure(figsize=(20,10))
title = sns.countplot(data["title"], palette="OrRd")
title = title.set_xticklabels(["Mr","Miss","Mrs","Master","Rare"])
# Out:
# C:\Users\kmk\anaconda3\envs\AI\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Define survavial rate predicted by features 'title' variable
title = sns.factorplot(x="title",y="survived",data=data,kind="bar", palette="OrRd", size=7, aspect=2)
title = title.set_xticklabels(["Mr","Miss","Mrs","Master","Rare"])
title = title.set_ylabels("survival probability")
# Out:
# C:\Users\kmk\anaconda3\envs\AI\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\kmk\anaconda3\envs\AI\lib\site-packages\seaborn\categorical.py:3723: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# - Next, we try to find a categorical feature with which the Age feature has the most relationship. In this way, we can categorize the dataset samples according to the categories of that categorical feature and fill the missing values in Age using the mean or median value of other values in the same category. In this way, we have been able to have a more accurate estimate for the missing values in Age. Let's plot boxplots of Age versus the dataset categorical features. We want to see that Age has different data distribution according to the categories of which of the features, so that we can use them to impute the missing data in Age:

# %%
# Define age range in passangers titles
plt.figure(figsize=(15,8))
sns.boxplot(data=data, x='title', y='age')
plt.show()

# %%
# Define age range in passangers titles
age_t = data.groupby(['title']).agg({'age': 'median'}).reset_index().sort_values(ascending = False, by='age')

display(age_t)
# Out:
#     title   age
# 4    Rare  45.0
# 3     Mrs  35.5
# 2      Mr  29.0
# 1    Miss  22.0
# 0  Master   4.0

# %%
# Define age range in passangers titles
age_t = data.groupby(['title', 'pclass']).agg({'age': 'median'}).reset_index()

display(age_t)
# Out:
#      title  pclass   age
# 0   Master       1   6.0
# 1   Master       2   2.0
# 2   Master       3   6.0
# 3     Miss       1  30.0
# 4     Miss       2  20.0
# 5     Miss       3  18.0
# 6       Mr       1  41.5
# 7       Mr       2  30.0
# 8       Mr       3  26.0
# 9      Mrs       1  45.0
# 10     Mrs       2  30.5
# 11     Mrs       3  31.0
# 12    Rare       1  47.0
# 13    Rare       2  41.5

# %%
# Defining correlation between study variables 
corrmat(data.corr(), inflate=False, figsize=(18, 15))
plt.show()

# %% [markdown]
# ### 6.3. Feature 'Cabin'

# %% [markdown]
# - Cabin feature is missing and the feature itself can't be ignored completely because some the cabins might have higher survival rates. It turns out to be the first letter of the Cabin values are the decks in which the cabins are located. Those decks were mainly separated for one passenger class, but some of them were used by multiple passenger classes.

# %% [markdown]
# ![Titanic_side_plan.webp](attachment:Titanic_side_plan.webp)

# %% [markdown]
# On the Boat Deck there were 6 rooms labeled as T, U, W, X, Y, Z but only the T cabin is present in the dataset
# - A, B and C decks were only for 1st class passengers
# - D and E decks were for all classes
# - F and G decks were for both 2nd and 3rd class passengers
# - From going A to G, distance to the staircase increases which might be a factor of survival

# %%
# Creating 'deck' column from the first letter of the 'cabin' column (M stands for Missing)
data['deck'] = data['cabin'].apply(lambda s: s[0] if pd.notnull(s) else 'M')

# %%
data['deck'].unique()
# Out:
# array(['B', 'C', 'E', 'D', 'A', 'M', 'T', 'F', 'G'], dtype=object)

# %%
data['deck'] = data['deck'].replace(['A', 'B', 'C'], 'ABC')
data['deck'] = data['deck'].replace(['D', 'E'], 'DE')
data['deck'] = data['deck'].replace(['F', 'G', 'T'], 'FGT')

data['deck'].value_counts()
# Out:
# M      1014
# ABC     181
# DE       87
# FGT      27
# Name: deck, dtype: int64

# %% [markdown]
# - A, B and C decks are labeled as ABC because all of them have only 1st class passengers
# - D and E decks are labeled as DE because both of them have similar passenger class distribution and same survival rate
# - F, G and T decks are labeled as FG because of the same reason above
# - M deck doesn't need to be grouped with other decks because it is very different from others and has the lowest survival rate.

# %%
title = sns.factorplot(x="deck",y="survived",data=data,kind="bar", palette="OrRd", size=6, aspect=2)
title = title.set_xticklabels(['M','ABC', 'DE', 'FGT'])
title = title.set_ylabels("survival probability")
# Out:
# C:\Users\kmk\anaconda3\envs\AI\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\kmk\anaconda3\envs\AI\lib\site-packages\seaborn\categorical.py:3723: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# - To conclude, cabins used by 1st class passengers have higher survival rates than cabins used by 2nd and 3rd class passengers. In my opinion M (Missing Cabin values) has the lowest survival rate because they couldn't retrieve the cabin data of the victims. That's why I believe labeling that group as M is a reasonable way to handle the missing data. It is a unique group with shared characteristics. Deck feature has high-cardinality right now so some of the values are grouped with each other based on their similarities.

# %% [markdown]
# ### 6.4. Dropping study variables

# %% [markdown]
# - Based on analysis and feature engineering I believe that we can remove some study variables that are not predicted by target. The following features 'cabin', 'boat', 'body', 'home.dest', 'name', 'ticket', 'embarked', 'is_alone', 'deck', 'fare', 'title' have been removed from the dataset before splitting to train and test. Some of these variables like 'body' 90%, 'home.dest' 43% that contain a lot of missing values can be removed. Though titles can be considered as an important predictor for survival in this study I decided to exclude it and keep pclass feature instead, because as we found eventually mostly 1st class passengers survived though there were a lot of infants and young passengers from the 2nd and 3rd classes, therefore I consider that at that point rather than title passengers' class played more vital role for their survival. 'names' and 'embarked' also were excluded in the reason that these features probably did not predict survival rate among passengers. Finally 'Is alone' variable has been removed because we have created 'family_size' feature that is also contain information about passangers that travelled alone.

# %%
# Dropping features from the dataset 
data.drop(['cabin', 'boat', 'body', 'home.dest', 'name', 'ticket', 'embarked', 'is_alone', 'deck', 'fare', 'title'], axis=1, inplace = True)

# %%
# Define dataset 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   pclass       1309 non-null   int64
#  1   survived     1309 non-null   int64
#  2   sex          1309 non-null   object
#  3   age          1309 non-null   float64
#  4   family_size  1309 non-null   int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 51.3+ KB

# %% [markdown]
# ## 7. Model Training

# %%
# Devide dataset to train and test 
x_train, x_test, y_train, y_test = train_test_split(data.drop('survived', axis = 1),
                                                   data['survived'], 
                                                   test_size = 0.3, 
                                                   random_state = 0)
x_train.shape, x_test.shape
# Out:
# ((916, 4), (393, 4))

# %%
# Create lists to record results 
model_list = []    

accuracy_list_train = []
accuracy_list_test = []
roc_auc_score_list_train = []
roc_auc_score_list_test = []
precision_score_list_train = []
precision_score_list_test = []
recall_score_list_train = []
recall_score_list_test = []
f1_score_list_train = []
f1_score_list_test = []

# %% [markdown]
# ### 7.1. RandomForestClassifier

# %%
# Define categorical variables
cat_list = [var for var in x_train.columns if x_train [var].dtype == 'O']
print('There are {} categorical variabls'.format(len(cat_list)))

# Define numerical variables
numeric_vars = [var for var in x_train.columns if x_train[var].dtype !='O']
print('There are {} numerical variabls'.format(len(numeric_vars)))
# Out:
# There are 1 categorical variabls
# There are 3 numerical variabls

# %%
# Show numeric vars 
numeric_vars
# Out:
# ['pclass', 'age', 'family_size']

# %%
# Show categorical vars 
cat_list
# Out:
# ['sex']

# %%
# Build Pipeline 
pipe_rfc = Pipeline([
    ('rare_label', RareLabelEncoder(tol = 0.05, n_categories = 3, variables = cat_list)),
    ('encoding', OrdinalEncoder(encoding_method='ordered', variables = cat_list)), 
    ('constant', DropConstantFeatures(tol = 0.91)),
    ('duplicated', DropDuplicateFeatures()),
    ('smart_corr_sel', SmartCorrelatedSelection()),
    ('rfc', RandomForestClassifier (random_state = 0))])

# %%
# Define grid search parameters 
rfc_param_grid = [{
    'rare_label__n_categories':[2, 3, 6],
    'encoding': [OrdinalEncoder(encoding_method = 'ordered'),
                CountFrequencyEncoder(encoding_method = 'count'), 
                OneHotEncoder()], 
    'rfc__min_samples_split' : [2, 4, 6, 8, 10],       # The minimum number of samples required to split an internal node
    'rfc__min_samples_leaf': [2, 3, 5, 7, 10],         # The minimum number of samples required to be at a leaf node       
    'rfc__criterion': ['gini', 'entropy'],             # The function to measure the quality of a split
    'rfc__n_estimators': [10, 30, 50, 100, 150],       # The number of trees in the forest
    'rfc__max_depth': [2, 4, 6, 8]                     # The maximum depth of the tree
}]

# %%
# Define grid search 
rfc_grid_search = GridSearchCV(estimator = pipe_rfc, param_grid = rfc_param_grid, cv = 5, 
                               n_jobs = -1, scoring = 'accuracy')

# %%
# Fit the model 
rfc_grid_search.fit(x_train, y_train)
# Out:
# C:\Users\kmk\anaconda3\envs\AI\lib\site-packages\feature_engine\encoding\rare_label.py:161: UserWarning: The number of unique categories for variable sex is less than that indicated in n_categories. Thus, all categories will be considered frequent
#   warnings.warn(
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('rare_label',
#                                         RareLabelEncoder(n_categories=3,
#                                                          variables=['sex'])),
#                                        ('encoding',
#                                         OrdinalEncoder(variables=['sex'])),
#                                        ('constant',
#                                         DropConstantFeatures(tol=0.91)),
#                                        ('duplicated', DropDuplicateFeatures()),
#                                        ('smart_corr_sel',
#                                         SmartCorrelatedSelection()),
# ...

# %%
# Define best parameters
rfc_grid_search.best_params_
# Out:
# {'encoding': CountFrequencyEncoder(),
#  'rare_label__n_categories': 2,
#  'rfc__criterion': 'entropy',
#  'rfc__max_depth': 4,
#  'rfc__min_samples_leaf': 2,
#  'rfc__min_samples_split': 6,
#  'rfc__n_estimators': 30}

# %%
# Define y_pred and print roc auc score metric 
rfc_y_pred_train = rfc_grid_search.predict(x_train)
rfc_y_pred_test = rfc_grid_search.predict(x_test)

print('Train set')
print('RandomForestClassifier roc-auc: {}'. format(roc_auc_score(y_train, rfc_y_pred_train)))

print('Test set')
print('RandomForestClassifier roc-auc: {}'. format(roc_auc_score(y_test, rfc_y_pred_test)))
# Out:
# Train set
# RandomForestClassifier roc-auc: 0.7983485878463714
# Test set
# RandomForestClassifier roc-auc: 0.7920192467230794

# %%
# Print classification report for the train set 
print(classification_report(y_train, rfc_y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.90      0.86       563
#            1       0.81      0.70      0.75       353
#
#     accuracy                           0.82       916
#    macro avg       0.82      0.80      0.81       916
# weighted avg       0.82      0.82      0.82       916

# %%
# Print classification report for the test set 
print(classification_report(y_test, rfc_y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.91      0.86       246
#            1       0.82      0.67      0.74       147
#
#     accuracy                           0.82       393
#    macro avg       0.82      0.79      0.80       393
# weighted avg       0.82      0.82      0.82       393

# %%
# Record the resutls 
model_list.append('RandomForestClassifier')
accuracy_list_train.append((accuracy_score(y_train, rfc_y_pred_train)))
accuracy_list_test.append((accuracy_score(y_test, rfc_y_pred_test)))

roc_auc_score_list_train.append((roc_auc_score(y_train, rfc_y_pred_train)))
roc_auc_score_list_test.append((roc_auc_score(y_test, rfc_y_pred_test)))

precision_score_list_train.append((precision_score(y_train, rfc_y_pred_train)))
precision_score_list_test.append((precision_score(y_test, rfc_y_pred_test)))

recall_score_list_train.append((recall_score(y_train, rfc_y_pred_train)))
recall_score_list_test.append((recall_score(y_test, rfc_y_pred_test)))

f1_score_list_train.append((f1_score(y_train, rfc_y_pred_train)))
f1_score_list_test.append((f1_score(y_test, rfc_y_pred_test)))

# %% [markdown]
# ### 7.2. LogisticRegression

# %%
# Build Pipeline 
pipe_lr = Pipeline([
    ('rare_label', RareLabelEncoder(tol = 0.05, n_categories = 3, variables = cat_list)),
    ('encoding', OrdinalEncoder(encoding_method='ordered', variables = cat_list)),
    ('scaler', StandardScaler()), 
    ('constant', DropConstantFeatures(tol = 0.91)),
    ('duplicated', DropDuplicateFeatures()),
    ('smart_corr_sel', SmartCorrelatedSelection()),
    ('lr', LogisticRegression (random_state = 0))])

# %%
# Define grid search parameters 
lr_param_grid = [{
    'rare_label__n_categories':[2, 3, 6],
    'encoding': [OrdinalEncoder(encoding_method = 'ordered'),
                CountFrequencyEncoder(encoding_method = 'count'), 
                OneHotEncoder()], 
    'scaler':[StandardScaler(), MinMaxScaler(), RobustScaler(), Normalizer()],
    'lr__penalty': ['l1', 'l2', 'elasticnet', 'none'], 
    'lr__solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'],
    'lr__max_iter': [100, 150, 200],
    'lr__C': [0.5, 1.0]
}]

# %%
# Define grid search  
lr_grid_search = GridSearchCV(estimator = pipe_lr, param_grid = lr_param_grid, 
                              cv = 5, n_jobs = -1, scoring = 'accuracy')

# %%
# Fit the model
lr_grid_search.fit(x_train, y_train)
# Out:
# C:\Users\kmk\anaconda3\envs\AI\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 9720 fits failed out of a total of 21600.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1080 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\kmk\anaconda3\envs\AI\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\kmk\anaconda3\envs\AI\lib\site-packages\sklearn\pipeline.py", line 394, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
# ...

# %%
# Define best parameters
lr_grid_search.best_params_
# Out:
# {'encoding': OrdinalEncoder(),
#  'lr__C': 0.5,
#  'lr__max_iter': 100,
#  'lr__penalty': 'l1',
#  'lr__solver': 'liblinear',
#  'rare_label__n_categories': 2,
#  'scaler': StandardScaler()}

# %%
# Define y_pred and print roc auc score metric 
lr_y_pred_train = lr_grid_search.predict(x_train)
lr_y_pred_test = lr_grid_search.predict(x_test)

print('Train set')
print('LogisticRegression roc-auc: {}'. format(roc_auc_score(y_train, lr_y_pred_train)))

print('Test set')
print('LogisticRegression roc-auc: {}'. format(roc_auc_score(y_test, lr_y_pred_test)))
# Out:
# Train set
# LogisticRegression roc-auc: 0.7722565777225406
# Test set
# LogisticRegression roc-auc: 0.7648498423759749

# %%
# Print classification report for the train set
print(classification_report(y_train, lr_y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.86      0.83       563
#            1       0.75      0.69      0.72       353
#
#     accuracy                           0.79       916
#    macro avg       0.78      0.77      0.78       916
# weighted avg       0.79      0.79      0.79       916

# %%
# Print classification report for the test set 
print(classification_report(y_test, lr_y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.89      0.85       246
#            1       0.78      0.64      0.70       147
#
#     accuracy                           0.80       393
#    macro avg       0.79      0.76      0.77       393
# weighted avg       0.79      0.80      0.79       393

# %%
# Record the resutls 
model_list.append('LogisticRegression')
accuracy_list_train.append((accuracy_score(y_train, lr_y_pred_train)))
accuracy_list_test.append((accuracy_score(y_test, lr_y_pred_test)))

roc_auc_score_list_train.append((roc_auc_score(y_train, lr_y_pred_train)))
roc_auc_score_list_test.append((roc_auc_score(y_test, lr_y_pred_test)))

precision_score_list_train.append((precision_score(y_train, lr_y_pred_train)))
precision_score_list_test.append((precision_score(y_test, lr_y_pred_test)))

recall_score_list_train.append((recall_score(y_train, lr_y_pred_train)))
recall_score_list_test.append((recall_score(y_test, lr_y_pred_test)))

f1_score_list_train.append((f1_score(y_train, lr_y_pred_train)))
f1_score_list_test.append((f1_score(y_test, lr_y_pred_test)))

# %% [markdown]
# ### 7.3. Gradient Boost Classifier

# %%
# Build pipeline
pipe_gbc = Pipeline([
    ('rare_label', RareLabelEncoder(tol = 0.05, n_categories = 3, variables = cat_list)),
    ('encoding', OrdinalEncoder(encoding_method='ordered', variables = cat_list)),
    ('scaler', StandardScaler()), 
    ('constant', DropConstantFeatures(tol = 0.91)),
    ('duplicated', DropDuplicateFeatures()),
    ('smart_corr_sel', SmartCorrelatedSelection()),
    ('gbc', GradientBoostingClassifier (random_state = 0))])

# %%
# Define grid search parameters 
gbc_param_grid = [{
    'rare_label__n_categories':[2, 3, 6],
    'encoding': [OrdinalEncoder(encoding_method = 'ordered'),
                CountFrequencyEncoder(encoding_method = 'count'), 
                OneHotEncoder()], 
    'scaler':[StandardScaler(), MinMaxScaler(), RobustScaler(), Normalizer()],
    'gbc__learning_rate' : [0.1, 0.01, 0.001, 0.5],    # The step size shrinkage used in update to prevent overfitting
    'gbc__min_samples_split': [2, 4, 6],               # The minimum number of samples required to split an internal node       
    'gbc__min_samples_leaf': [1, 3, 5, 10, 50, 100],   # The minimum number of samples required to be at a leaf node
    'gbc__n_estimators': [10, 30, 70, 100],            # The number of trees in the forest
    'gbc__max_depth': [2, 4, 6, 8]                     # The maximum depth of the tree
}]

# %%
# Define grid search  
gbc_grid_search = GridSearchCV(estimator = pipe_gbc, param_grid = gbc_param_grid, cv = 5, 
                               n_jobs = -1, scoring = 'accuracy')

# %%
# Fit the model 
gbc_grid_search.fit(x_train, y_train)
# Out:
# C:\Users\kmk\anaconda3\envs\AI\lib\site-packages\feature_engine\encoding\rare_label.py:161: UserWarning: The number of unique categories for variable sex is less than that indicated in n_categories. Thus, all categories will be considered frequent
#   warnings.warn(
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('rare_label',
#                                         RareLabelEncoder(n_categories=3,
#                                                          variables=['sex'])),
#                                        ('encoding',
#                                         OrdinalEncoder(variables=['sex'])),
#                                        ('scaler', StandardScaler()),
#                                        ('constant',
#                                         DropConstantFeatures(tol=0.91)),
#                                        ('duplicated', DropDuplicateFeatures()),
#                                        ('smart_corr_sel',
# ...

# %%
# Define best parameters
gbc_grid_search.best_params_
# Out:
# {'encoding': OrdinalEncoder(),
#  'gbc__learning_rate': 0.1,
#  'gbc__max_depth': 4,
#  'gbc__min_samples_leaf': 3,
#  'gbc__min_samples_split': 2,
#  'gbc__n_estimators': 30,
#  'rare_label__n_categories': 2,
#  'scaler': StandardScaler()}

# %%
# Define y_pred and print roc auc score metric 
gbc_y_pred_train = gbc_grid_search.predict(x_train)
gbc_y_pred_test = gbc_grid_search.predict(x_test)

print('Train set')
print('Gradient Boosting Classifier roc-auc: {}'. format(roc_auc_score(y_train, gbc_y_pred_train)))

print('Test set')
print('Gradient Boosting Classifier roc-auc: {}'. format(roc_auc_score(y_test, gbc_y_pred_test)))
# Out:
# Train set
# Gradient Boosting Classifier roc-auc: 0.805644589134493
# Test set
# Gradient Boosting Classifier roc-auc: 0.7838476854156297

# %%
# Print classification report for the train set
print(classification_report(y_train, gbc_y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.92      0.87       563
#            1       0.84      0.69      0.76       353
#
#     accuracy                           0.83       916
#    macro avg       0.84      0.81      0.82       916
# weighted avg       0.83      0.83      0.83       916

# %%
# Print classification report for the test set 
print(classification_report(y_test, gbc_y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.91      0.86       246
#            1       0.82      0.65      0.73       147
#
#     accuracy                           0.82       393
#    macro avg       0.82      0.78      0.79       393
# weighted avg       0.82      0.82      0.81       393

# %%
# Record the resutls 
model_list.append('Gradient Boosting Classifier')
accuracy_list_train.append((accuracy_score(y_train, gbc_y_pred_train)))
accuracy_list_test.append((accuracy_score(y_test, gbc_y_pred_test)))

roc_auc_score_list_train.append((roc_auc_score(y_train, gbc_y_pred_train)))
roc_auc_score_list_test.append((roc_auc_score(y_test, gbc_y_pred_test)))

precision_score_list_train.append((precision_score(y_train, gbc_y_pred_train)))
precision_score_list_test.append((precision_score(y_test, gbc_y_pred_test)))

recall_score_list_train.append((recall_score(y_train, gbc_y_pred_train)))
recall_score_list_test.append((recall_score(y_test, gbc_y_pred_test)))

f1_score_list_train.append((f1_score(y_train, gbc_y_pred_train)))
f1_score_list_test.append((f1_score(y_test, gbc_y_pred_test)))

# %% [markdown]
# ### 7.4. XGB Classifier

# %%
# Build pipeline
pipe_xgb = Pipeline([
    ('rare_label', RareLabelEncoder(tol = 0.05, n_categories = 3, variables = cat_list)),
    ('encoding', OrdinalEncoder(encoding_method='ordered', variables = cat_list)),
    ('constant', DropConstantFeatures(tol = 0.91)),
    ('duplicated', DropDuplicateFeatures()),
    ('smart_corr_sel', SmartCorrelatedSelection()),
    ('xgb', XGBClassifier (random_state = 0))])

# %%
# Define grid search parameters 
xgb_param_grid = [{
    'rare_label__n_categories':[2, 3, 6],
    'encoding': [OrdinalEncoder(encoding_method = 'ordered'),
                CountFrequencyEncoder(encoding_method = 'count'), 
                OneHotEncoder()], 
    'xgb__colsample_bytree': [0.5, 0.8, 1],       # Subsample ratio of columns when constructing each tree
    'xgb__learning_rate': [0.1, 0.01, 0.001],     # Boosting learning rate (xgb’s “eta”)    
    'xgb__max_delta_step': [1, 3, 5],             # Maximum delta step for each leaf. 
    'xgb__n_estimators': [20, 50, 100],           # Number of trees in the forest
    'xgb__max_depth': [2, 4, 6],                  # Maximum depth of a tree
}]

# %%
# Define grid search  
xgb_grid_search = GridSearchCV(estimator = pipe_xgb, param_grid = xgb_param_grid, cv = 5, 
                               n_jobs = -1, scoring = 'accuracy')

# %%
# Fit model 
xgb_grid_search.fit(x_train, y_train)
# Out:
# [07:04:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# C:\Users\kmk\anaconda3\envs\AI\lib\site-packages\feature_engine\encoding\rare_label.py:161: UserWarning: The number of unique categories for variable sex is less than that indicated in n_categories. Thus, all categories will be considered frequent
#   warnings.warn(
# C:\Users\kmk\anaconda3\envs\AI\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
# ...

# %%
# Define best parameters 
xgb_grid_search.best_params_
# Out:
# {'encoding': OrdinalEncoder(),
#  'rare_label__n_categories': 2,
#  'xgb__colsample_bytree': 1,
#  'xgb__learning_rate': 0.01,
#  'xgb__max_delta_step': 1,
#  'xgb__max_depth': 4,
#  'xgb__n_estimators': 50}

# %%
# Define y_pred and print roc auc score metric 
xgb_y_pred_train = xgb_grid_search.predict(x_train)
xgb_y_pred_test = xgb_grid_search.predict(x_test)

print('Train set')
print('XGBClassifier roc-auc: {}'. format(roc_auc_score(y_train, xgb_y_pred_train)))

print('Test set')
print('XGBClassifier roc-auc: {}'. format(roc_auc_score(y_test, xgb_y_pred_test)))
# Out:
# Train set
# XGBClassifier roc-auc: 0.7951786010798081
# Test set
# XGBClassifier roc-auc: 0.790650406504065
# C:\Users\kmk\anaconda3\envs\AI\lib\site-packages\xgboost\data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\kmk\anaconda3\envs\AI\lib\site-packages\xgboost\data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):

# %%
# Print classification report for the train set 
print(classification_report(y_train, xgb_y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.91      0.86       563
#            1       0.82      0.68      0.75       353
#
#     accuracy                           0.82       916
#    macro avg       0.82      0.80      0.80       916
# weighted avg       0.82      0.82      0.82       916

# %%
# Print classification report for the test set 
print(classification_report(y_test, xgb_y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.91      0.87       246
#            1       0.82      0.67      0.74       147
#
#     accuracy                           0.82       393
#    macro avg       0.82      0.79      0.80       393
# weighted avg       0.82      0.82      0.82       393

# %%
# Record the resutls 
model_list.append('XGBClassifier')
accuracy_list_train.append((accuracy_score(y_train, xgb_y_pred_train)))
accuracy_list_test.append((accuracy_score(y_test, xgb_y_pred_test)))

roc_auc_score_list_train.append((roc_auc_score(y_train, xgb_y_pred_train)))
roc_auc_score_list_test.append((roc_auc_score(y_test, xgb_y_pred_test)))

precision_score_list_train.append((precision_score(y_train, xgb_y_pred_train)))
precision_score_list_test.append((precision_score(y_test, xgb_y_pred_test)))

recall_score_list_train.append((recall_score(y_train, xgb_y_pred_train)))
recall_score_list_test.append((recall_score(y_test, xgb_y_pred_test)))

f1_score_list_train.append((f1_score(y_train, xgb_y_pred_train)))
f1_score_list_test.append((f1_score(y_test, xgb_y_pred_test)))

# %% [markdown]
# ### 7.5. AdaBoostClassifier

# %%
# Buid pipeline 
pipe_abc = Pipeline([
    ('rare_label', RareLabelEncoder(tol = 0.05, n_categories = 3, variables = cat_list)),
    ('encoding', OrdinalEncoder(encoding_method='ordered', variables = cat_list)),
    ('scaler', StandardScaler()), 
    ('constant', DropConstantFeatures(tol = 0.91)),
    ('duplicated', DropDuplicateFeatures()),
    ('smart_corr_sel', SmartCorrelatedSelection()),
    ('abc', AdaBoostClassifier (random_state = 0))])

# %%
# Define grid search parameters 
abc_param_grid = [{
    'rare_label__n_categories':[2, 3, 6],
    'encoding': [OrdinalEncoder(encoding_method = 'ordered'),
                CountFrequencyEncoder(encoding_method = 'count'), 
                OneHotEncoder()], 
    'scaler':[StandardScaler(), MinMaxScaler(), RobustScaler(), Normalizer()],
    'abc__n_estimators' : [10, 30, 70, 100, 150],           # The number of base estimators we use in our dataset
    'abc__learning_rate': [0.0001, 0.001, 0.01, 0.1, 1.0]   # The step size shrinkage used in update to prevent overfitting     
}]

# %%
# Define grid search  
abc_grid_search = GridSearchCV(estimator = pipe_abc, param_grid = abc_param_grid, cv = 5, 
                               n_jobs = -1, scoring = 'accuracy')

# %%
# Fit model
abc_grid_search.fit(x_train, y_train)
# Out:
# C:\Users\kmk\anaconda3\envs\AI\lib\site-packages\feature_engine\encoding\rare_label.py:161: UserWarning: The number of unique categories for variable sex is less than that indicated in n_categories. Thus, all categories will be considered frequent
#   warnings.warn(
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('rare_label',
#                                         RareLabelEncoder(n_categories=3,
#                                                          variables=['sex'])),
#                                        ('encoding',
#                                         OrdinalEncoder(variables=['sex'])),
#                                        ('scaler', StandardScaler()),
#                                        ('constant',
#                                         DropConstantFeatures(tol=0.91)),
#                                        ('duplicated', DropDuplicateFeatures()),
#                                        ('smart_corr_sel',
# ...

# %%
# Define best parameters
abc_grid_search.best_params_
# Out:
# {'abc__learning_rate': 0.1,
#  'abc__n_estimators': 150,
#  'encoding': OrdinalEncoder(),
#  'rare_label__n_categories': 2,
#  'scaler': StandardScaler()}

# %%
# Define y_pred and print roc auc score metric 
abc_y_pred_train = abc_grid_search.predict(x_train)
abc_y_pred_test = abc_grid_search.predict(x_test)

print('Train set')
print('AdaBoost Classifier roc-auc: {}'. format(roc_auc_score(y_train, abc_y_pred_train)))

print('Test set')
print('AdaBoost Classifier roc-auc: {}'. format(roc_auc_score(y_test, abc_y_pred_test)))
# Out:
# Train set
# AdaBoost Classifier roc-auc: 0.7798897045874237
# Test set
# AdaBoost Classifier roc-auc: 0.7573834411813506

# %%
# Print classification report for the train set 
print(classification_report(y_train, abc_y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.87      0.84       563
#            1       0.77      0.69      0.73       353
#
#     accuracy                           0.80       916
#    macro avg       0.79      0.78      0.78       916
# weighted avg       0.80      0.80      0.80       916

# %%
# Print classification report for the test set 
print(classification_report(y_test, abc_y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.88      0.84       246
#            1       0.76      0.63      0.69       147
#
#     accuracy                           0.79       393
#    macro avg       0.78      0.76      0.77       393
# weighted avg       0.79      0.79      0.78       393

# %%
# Record the resutls 
model_list.append('AdaBoost Classifier')
accuracy_list_train.append((accuracy_score(y_train, abc_y_pred_train)))
accuracy_list_test.append((accuracy_score(y_test, abc_y_pred_test)))

roc_auc_score_list_train.append((roc_auc_score(y_train, abc_y_pred_train)))
roc_auc_score_list_test.append((roc_auc_score(y_test, abc_y_pred_test)))

precision_score_list_train.append((precision_score(y_train, abc_y_pred_train)))
precision_score_list_test.append((precision_score(y_test, abc_y_pred_test)))

recall_score_list_train.append((recall_score(y_train, abc_y_pred_train)))
recall_score_list_test.append((recall_score(y_test, abc_y_pred_test)))

f1_score_list_train.append((f1_score(y_train, abc_y_pred_train)))
f1_score_list_test.append((f1_score(y_test, abc_y_pred_test)))

# %% [markdown]
# ### 7.6. KNeighbors Classifier

# %%
# Build pipeline 
pipe_knc = Pipeline([
    ('rare_label', RareLabelEncoder(tol = 0.05, n_categories = 3, variables = cat_list)),
    ('encoding', OrdinalEncoder(encoding_method='ordered', variables = cat_list)),
    ('scaler', StandardScaler()), 
    ('constant', DropConstantFeatures(tol = 0.91)),
    ('duplicated', DropDuplicateFeatures()),
    ('smart_corr_sel', SmartCorrelatedSelection()),
    ('knc', KNeighborsClassifier())])

# %%
# Define grid search parameters 
knc_param_grid = [{
    'rare_label__n_categories':[2, 3, 6],
    'encoding': [OrdinalEncoder(encoding_method = 'ordered'),
                CountFrequencyEncoder(encoding_method = 'count'), 
                OneHotEncoder()], 
    'scaler':[StandardScaler(), MinMaxScaler(), RobustScaler(), Normalizer()],
    'knc__weights' : ['uniform', 'distance'],  # Weight function used in prediction
    'knc__n_neighbors': [1, 3, 5],             # Number of neighbors to use   
    'knc__p': [1, 2, 3]                        # Power parameter for the Minkowski metric
}]

# %%
# Define grid search  
knc_grid_search = GridSearchCV(estimator = pipe_knc, param_grid = knc_param_grid, cv = 5, 
                               n_jobs = -1, scoring = 'accuracy')

# %%
# Fit model
knc_grid_search.fit(x_train, y_train)
# Out:
# C:\Users\kmk\anaconda3\envs\AI\lib\site-packages\feature_engine\encoding\rare_label.py:161: UserWarning: The number of unique categories for variable sex is less than that indicated in n_categories. Thus, all categories will be considered frequent
#   warnings.warn(
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('rare_label',
#                                         RareLabelEncoder(n_categories=3,
#                                                          variables=['sex'])),
#                                        ('encoding',
#                                         OrdinalEncoder(variables=['sex'])),
#                                        ('scaler', StandardScaler()),
#                                        ('constant',
#                                         DropConstantFeatures(tol=0.91)),
#                                        ('duplicated', DropDuplicateFeatures()),
#                                        ('smart_corr_sel',
# ...

# %%
# Define best parameters 
knc_grid_search.best_params_
# Out:
# {'encoding': CountFrequencyEncoder(),
#  'knc__n_neighbors': 3,
#  'knc__p': 1,
#  'knc__weights': 'uniform',
#  'rare_label__n_categories': 2,
#  'scaler': MinMaxScaler()}

# %%
# Define y_pred and print roc auc score metric 
knc_y_pred_train = knc_grid_search.predict(x_train)
knc_y_pred_test = knc_grid_search.predict(x_test)

print('Train set')
print('KNeighbors Classifier roc-auc: {}'. format(roc_auc_score(y_train, knc_y_pred_train)))

print('Test set')
print('KNeighbors Classifier roc-auc: {}'. format(roc_auc_score(y_test, knc_y_pred_test)))
# Out:
# Train set
# KNeighbors Classifier roc-auc: 0.8369293394854559
# Test set
# KNeighbors Classifier roc-auc: 0.7384270781483325
# C:\Users\kmk\anaconda3\envs\AI\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# ...

# %%
# Print classification report for the train set 
print(classification_report(y_train, knc_y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.89      0.88       563
#            1       0.81      0.79      0.80       353
#
#     accuracy                           0.85       916
#    macro avg       0.84      0.84      0.84       916
# weighted avg       0.85      0.85      0.85       916

# %%
# Print classification report for the test set 
print(classification_report(y_test, knc_y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.84      0.82       246
#            1       0.70      0.64      0.67       147
#
#     accuracy                           0.76       393
#    macro avg       0.75      0.74      0.74       393
# weighted avg       0.76      0.76      0.76       393

# %%
# Record the resutls 
model_list.append('KNeighbors Classifier')
accuracy_list_train.append((accuracy_score(y_train, knc_y_pred_train)))
accuracy_list_test.append((accuracy_score(y_test, knc_y_pred_test)))

roc_auc_score_list_train.append((roc_auc_score(y_train, knc_y_pred_train)))
roc_auc_score_list_test.append((roc_auc_score(y_test, knc_y_pred_test)))

precision_score_list_train.append((precision_score(y_train, knc_y_pred_train)))
precision_score_list_test.append((precision_score(y_test, knc_y_pred_test)))

recall_score_list_train.append((recall_score(y_train, knc_y_pred_train)))
recall_score_list_test.append((recall_score(y_test, knc_y_pred_test)))

f1_score_list_train.append((f1_score(y_train, knc_y_pred_train)))
f1_score_list_test.append((f1_score(y_test, knc_y_pred_test)))

# %% [markdown]
# ### 7.7. Decision Tree Classifier

# %%
# Build pipeline

pipe_dtc = Pipeline([
    ('rare_label', RareLabelEncoder(tol = 0.05, n_categories = 3, variables = cat_list)),
    ('encoding', OrdinalEncoder(encoding_method='ordered', variables = cat_list)),
    ('constant', DropConstantFeatures(tol = 0.91)),
    ('duplicated', DropDuplicateFeatures()),
    ('smart_corr_sel', SmartCorrelatedSelection()),
    ('dtc', DecisionTreeClassifier (random_state = 0))])

# %%
# Define grid search parameters 
dtc_param_grid = [{
    'rare_label__n_categories':[2, 3, 6],
    'encoding': [OrdinalEncoder(encoding_method = 'ordered'),
                CountFrequencyEncoder(encoding_method = 'count'), 
                OneHotEncoder()], 
    'dtc__min_samples_split': [2, 4, 6],           # The minimum number of samples required to split an internal node
    'dtc__min_samples_leaf': [1, 2, 5],            # The minimum number of samples required to be at a leaf node    
    'dtc__criterion': ['gini', 'entropy'],         # The function to measure the quality of a split.
    'dtc__max_depth': [2, 4, 6],                   # The maximum depth of the tree
}]

# %%
# Define grid search  
dtc_grid_search = GridSearchCV(estimator = pipe_dtc, param_grid = dtc_param_grid, cv = 5, 
                               n_jobs = -1, scoring = 'accuracy')

# %%
# Build model
dtc_grid_search.fit(x_train, y_train)
# Out:
# C:\Users\kmk\anaconda3\envs\AI\lib\site-packages\feature_engine\encoding\rare_label.py:161: UserWarning: The number of unique categories for variable sex is less than that indicated in n_categories. Thus, all categories will be considered frequent
#   warnings.warn(
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('rare_label',
#                                         RareLabelEncoder(n_categories=3,
#                                                          variables=['sex'])),
#                                        ('encoding',
#                                         OrdinalEncoder(variables=['sex'])),
#                                        ('scaler', StandardScaler()),
#                                        ('constant',
#                                         DropConstantFeatures(tol=0.91)),
#                                        ('duplicated', DropDuplicateFeatures()),
#                                        ('smart_corr_sel',
# ...

# %%
# Define best parameters 
dtc_grid_search.best_params_
# Out:
# {'dtc__criterion': 'gini',
#  'dtc__max_depth': 4,
#  'dtc__min_samples_leaf': 5,
#  'dtc__min_samples_split': 2,
#  'encoding': OrdinalEncoder(),
#  'rare_label__n_categories': 2,
#  'scaler': StandardScaler()}

# %%
# Define y_pred and print roc auc score metric 
dtc_y_pred_train = dtc_grid_search.predict(x_train)
dtc_y_pred_test = dtc_grid_search.predict(x_test)

print('Train set')
print('Decision Tree Classifier roc-auc: {}'. format(roc_auc_score(y_train, dtc_y_pred_train)))

print('Test set')
print('Decision Tree Classifier roc-auc: {}'. format(roc_auc_score(y_test, dtc_y_pred_test)))
# Out:
# Train set
# Decision Tree Classifier roc-auc: 0.7951786010798081
# Test set
# Decision Tree Classifier roc-auc: 0.790650406504065

# %%
# Print classification report for the train set 
print(classification_report(y_train, dtc_y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.91      0.86       563
#            1       0.82      0.68      0.75       353
#
#     accuracy                           0.82       916
#    macro avg       0.82      0.80      0.80       916
# weighted avg       0.82      0.82      0.82       916

# %%
# Print classification report for the test set 
print(classification_report(y_test, dtc_y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.91      0.87       246
#            1       0.82      0.67      0.74       147
#
#     accuracy                           0.82       393
#    macro avg       0.82      0.79      0.80       393
# weighted avg       0.82      0.82      0.82       393

# %%
# Record the resutls 
model_list.append('Decision Tree Classifier')
accuracy_list_train.append((accuracy_score(y_train, dtc_y_pred_train)))
accuracy_list_test.append((accuracy_score(y_test, dtc_y_pred_test)))

roc_auc_score_list_train.append((roc_auc_score(y_train, dtc_y_pred_train)))
roc_auc_score_list_test.append((roc_auc_score(y_test, dtc_y_pred_test)))

precision_score_list_train.append((precision_score(y_train, dtc_y_pred_train)))
precision_score_list_test.append((precision_score(y_test, dtc_y_pred_test)))

recall_score_list_train.append((recall_score(y_train, dtc_y_pred_train)))
recall_score_list_test.append((recall_score(y_test, dtc_y_pred_test)))

f1_score_list_train.append((f1_score(y_train, dtc_y_pred_train)))
f1_score_list_test.append((f1_score(y_test, dtc_y_pred_test)))

# %% [markdown]
# ### 7.8. SVC

# %%
# Build pipeline
pipe_svc = Pipeline([
    ('rare_label', RareLabelEncoder(tol = 0.05, n_categories = 3, variables = cat_list)),
    ('encoding', OrdinalEncoder(encoding_method='ordered', variables = cat_list)),
    ('scaler', StandardScaler()), 
    ('constant', DropConstantFeatures(tol = 0.91)),
    ('duplicated', DropDuplicateFeatures()),
    ('smart_corr_sel', SmartCorrelatedSelection()),
    ('svc', SVC ())])

# %%
# Define grid search parameters 
svc_param_grid = [{
    'rare_label__n_categories':[2, 3, 6],
    'encoding': [OrdinalEncoder(encoding_method = 'ordered'),
                CountFrequencyEncoder(encoding_method = 'count'), 
                OneHotEncoder()], 
    'scaler':[StandardScaler(), MinMaxScaler(), RobustScaler(), Normalizer()],
    'svc__kernel': ['linear', 'poly', 'rbf'],       # Specifies the kernel type to be used in the algorithm
    'svc__gamma': ['scale', 'auto'],                # Kernel coefficient for 'rbf', 'poly' and 'sigmoid'
    'svc__degree': [2, 3, 4],                       # Degree of the polynomial kernel function
    'svc__C': [0.1, 1, 10],                         # Penalty parameter C of the error term
}]

# %%
# Define grid search 
svc_grid_search = GridSearchCV(estimator = pipe_svc, param_grid = svc_param_grid, cv = 5, 
                               n_jobs = -1, scoring = 'accuracy')

# %%
# Fit model
svc_grid_search.fit(x_train, y_train)
# Out:
# C:\Users\kmk\anaconda3\envs\AI\lib\site-packages\feature_engine\encoding\rare_label.py:161: UserWarning: The number of unique categories for variable sex is less than that indicated in n_categories. Thus, all categories will be considered frequent
#   warnings.warn(
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('rare_label',
#                                         RareLabelEncoder(n_categories=3,
#                                                          variables=['sex'])),
#                                        ('encoding',
#                                         OrdinalEncoder(variables=['sex'])),
#                                        ('scaler', StandardScaler()),
#                                        ('constant',
#                                         DropConstantFeatures(tol=0.91)),
#                                        ('duplicated', DropDuplicateFeatures()),
#                                        ('smart_corr_sel',
# ...

# %%
# Define best parameters
svc_grid_search.best_params_
# Out:
# {'encoding': CountFrequencyEncoder(),
#  'rare_label__n_categories': 2,
#  'scaler': RobustScaler(),
#  'svc__C': 10,
#  'svc__degree': 2,
#  'svc__gamma': 'scale',
#  'svc__kernel': 'rbf'}

# %%
# Define y_pred and print roc auc score metric 
svc_y_pred_train = svc_grid_search.predict(x_train)
svc_y_pred_test = svc_grid_search.predict(x_test)

print('Train set')
print('Decision Tree Classifier roc-auc: {}'. format(roc_auc_score(y_train, svc_y_pred_train)))

print('Test set')
print('Decision Tree Classifier roc-auc: {}'. format(roc_auc_score(y_test, svc_y_pred_test)))
# Out:
# Train set
# Decision Tree Classifier roc-auc: 0.8000795012554154
# Test set
# Decision Tree Classifier roc-auc: 0.790028206404513

# %%
# Print classification report for the train set 
print(classification_report(y_train, svc_y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.87      0.85       563
#            1       0.78      0.73      0.75       353
#
#     accuracy                           0.82       916
#    macro avg       0.81      0.80      0.80       916
# weighted avg       0.82      0.82      0.82       916

# %%
# Print classification report for the test set 
print(classification_report(y_test, svc_y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.89      0.86       246
#            1       0.78      0.69      0.74       147
#
#     accuracy                           0.81       393
#    macro avg       0.81      0.79      0.80       393
# weighted avg       0.81      0.81      0.81       393

# %%
# Record the resutls 
model_list.append('SVC')
accuracy_list_train.append((accuracy_score(y_train, svc_y_pred_train)))
accuracy_list_test.append((accuracy_score(y_test, svc_y_pred_test)))

roc_auc_score_list_train.append((roc_auc_score(y_train, svc_y_pred_train)))
roc_auc_score_list_test.append((roc_auc_score(y_test, svc_y_pred_test)))

precision_score_list_train.append((precision_score(y_train, svc_y_pred_train)))
precision_score_list_test.append((precision_score(y_test, svc_y_pred_test)))

recall_score_list_train.append((recall_score(y_train, svc_y_pred_train)))
recall_score_list_test.append((recall_score(y_test, svc_y_pred_test)))

f1_score_list_train.append((f1_score(y_train, svc_y_pred_train)))
f1_score_list_test.append((f1_score(y_test, svc_y_pred_test)))

# %% [markdown]
# ##  8. Model Evaluation

# %%
# Evaluate recorded results from the lists  
model_results = pd.DataFrame({'Model': model_list, 
                              'accuracy_train': accuracy_list_train,
                              'accuracy_test': accuracy_list_test,
                              'roc_auc_train': roc_auc_score_list_train,
                              'roc_auc_test': roc_auc_score_list_test,
                              'precision_train': precision_score_list_train,
                              'precision_test': precision_score_list_test,
                              'recall_train': recall_score_list_train,
                              'recall_test': recall_score_list_test,
                              'f1_score_train': f1_score_list_train,
                              'f1_score_test': f1_score_list_test,
                             })

model_results.sort_values(by = 'accuracy_test', ascending = False)
# Out:
#                           Model  accuracy_train  accuracy_test  roc_auc_train  \
# 0                 XGBClassifier        0.820961       0.821883       0.795179
# 1        RandomForestClassifier        0.820961       0.821883       0.798349
# 4                 XGBClassifier        0.820961       0.821883       0.795179
# 7      Decision Tree Classifier        0.820961       0.821883       0.795179
# 3  Gradient Boosting Classifier        0.831878       0.816794       0.805645
# 8                           SVC        0.816594       0.814249       0.800080
# 2            LogisticRegression        0.791485       0.796438       0.772257
# 5           AdaBoost Classifier        0.800218       0.788804       0.779890
# 6         KNeighbors Classifier        0.848253       0.763359       0.836929
#
#    roc_auc_test  precision_train  precision_test  recall_train  recall_test  \
# 0      0.790650         0.822526        0.823529      0.682720     0.666667
# ...

# %% [markdown]
# ### 8.1. Accuracy Train Score

# %%
# Show accuracy score for the train set
plt.figure(figsize=(10, 5))
sns.barplot(data = model_results.sort_values(by ='accuracy_train', ascending = False), 
            x = 'accuracy_train', y = 'Model', palette = 'tab20c_r')
plt.title("Accuracy Train Score")
plt.show()

# %% [markdown]
# ### 8.2. Accuracy Test Score

# %%
# Show accuracy score for the test set
plt.figure(figsize=(10, 5))
sns.barplot(data = model_results.sort_values(by ='accuracy_test', ascending = False), 
            x = 'accuracy_test', y = 'Model', palette = 'tab20c_r')
plt.title("Accuracy Test Score")
plt.show()

# %% [markdown]
# ### 8.3. Roc Auc Train Score

# %%
# Show roc auc score for the train set
plt.figure(figsize=(10, 5))
sns.barplot(data = model_results.sort_values(by ='roc_auc_train', ascending = False), 
            x = 'roc_auc_train', y = 'Model', palette = 'tab20c_r')
plt.title("Roc_auc Train Score")
plt.show()

# %% [markdown]
# ### 8.3. Roc Auc Test Score

# %%
# Show roc auc score for the test set
plt.figure(figsize=(10, 5))
sns.barplot(data = model_results.sort_values(by ='roc_auc_test', ascending = False), 
            x = 'roc_auc_test', y = 'Model', palette = 'tab20c_r')
plt.title("Roc_auc Test Score")
plt.show()

# %% [markdown]
# ### 8.4. Precision Train Score

# %%
# Show precision score for the train set
plt.figure(figsize=(10, 5))
sns.barplot(data = model_results.sort_values(by ='precision_train', ascending = False), 
            x = 'precision_train', y = 'Model', palette = 'tab20c_r')
plt.title("Precision Train Score")
plt.show()

# %% [markdown]
# ### 8.5. Precision Test Score

# %%
# Show precision score for the test set
plt.figure(figsize=(10, 5))
sns.barplot(data = model_results.sort_values(by ='precision_test', ascending = False), 
            x = 'precision_test', y = 'Model', palette = 'tab20c_r')
plt.title("Precision Test Score")
plt.show()

# %% [markdown]
# ### 8.6. Recall Train Score

# %%
# Show recall score for the train set
plt.figure(figsize=(10, 5))
sns.barplot(data = model_results.sort_values(by ='recall_train', ascending = False), 
            x = 'recall_train', y = 'Model', palette = 'tab20c_r')
plt.title("Recall Train Score")
plt.show()

# %% [markdown]
# ### 8.4. Recall Test Score

# %%
# Show recall score for the test set
plt.figure(figsize=(10, 5))
sns.barplot(data = model_results.sort_values(by ='recall_test', ascending = False), 
            x = 'recall_test', y = 'Model', palette = 'tab20c_r')
plt.title("Recall Test Score")
plt.show()

# %% [markdown]
# ### 8.5. F1 Train Score

# %%
# Show f1 score for the train set
plt.figure(figsize=(10, 5))
sns.barplot(data = model_results.sort_values(by ='f1_score_train', ascending = False), 
            x = 'f1_score_train', y = 'Model', palette = 'tab20c_r')
plt.title("F1_score Train Score")
plt.show()

# %% [markdown]
# ### 8.6. F1 Test Score

# %%
# Show f1 score for the test set
plt.figure(figsize=(10, 5))
sns.barplot(data = model_results.sort_values(by ='f1_score_test', ascending = False), 
            x = 'f1_score_test', y = 'Model', palette = 'tab20c_r')
plt.title("F1_score Test Score")
plt.show()

# %% [markdown]
# ### 8.7. Confusion Matrix

# %%
# Visualise errors through the confusion matrix 
fig, axs = plt.subplots(ncols = 4, nrows = 2, figsize = (20, 9))

plot_confusion_matrix(rfc_grid_search, x_test, y_test, ax = axs[0][0], colorbar=False)
axs[0][0].set_title('Random Forest Classifier')

plot_confusion_matrix(lr_grid_search, x_test, y_test, ax = axs[0][1], colorbar=False)
axs[0][1].set_title('Logistic Regression')

plot_confusion_matrix(dtc_grid_search, x_test, y_test, ax = axs[0][2], colorbar=False)
axs[0][2].set_title('Decision Tree Classifier')

plot_confusion_matrix(dtc_grid_search, x_test, y_test, ax = axs[0][3], colorbar=False)
axs[0][3].set_title('SVC')

plot_confusion_matrix(xgb_grid_search, x_test, y_test, ax = axs[1][0], colorbar=False)
axs[1][0].set_title('XGBClassifier')
                                                                  
plot_confusion_matrix(abc_grid_search, x_test, y_test, ax = axs[1][1], colorbar=False)
axs[1][1].set_title('AdaBoost Classifier')
                                                                
plot_confusion_matrix(knc_grid_search, x_test, y_test, ax = axs[1][2], colorbar=False)
axs[1][2].set_title('KNeighbors Classifier')

plot_confusion_matrix(gbc_grid_search, x_test, y_test, ax = axs[1][3], colorbar=False)
axs[1][3].set_title('Gradient Boosting Classifier')
                                                                

fig.tight_layout()
# Out:
# C:\Users\kmk\anaconda3\envs\AI\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\kmk\anaconda3\envs\AI\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# ...

# %% [markdown]
# Confusion Matrix tells us how many our model predicted correctly and incorrectly in terms of binary/multiple outcome classes by comparing actual and predicted cases. For example, in terms of this dataset, our model is a binary one and we are trying to classify whether the passenger survived or not survived. we have fit the model using x_train and y_train and predicted the outcome of x_test in the variable y_pred.
#
# - True Positive(TP): values that the model predicted as yes(survived) and is actually yes(survived).
# - True Negative(TN): values that model predicted as no(not-survived) and is actually no(not-survived)
# - False Positive(or Type I error): values that model predicted as yes(survived) but actually no(not-survived)
# - False Negative(or Type II error): values that model predicted as no(not-survived) but actually yes(survived)
# - For this dataset, whenever the model is predicting something as yes, it means the model is predicting that the passenger survived and for cases when the model predicting no; it means the passenger did not survive.

# %% [markdown]
# ##  9. Testing Model

# %%
# Recording best estimators to the new variable 
model = xgb_grid_search.best_estimator_

# %%
# Testing the best model input and output 
testing_pclass = int(input('Passanger pclass: '))
testing_age = int(input('Passanger age: '))
testing_sex = input('Passanger sex: ')
testing_family_size = int(input('Passanger family_size: '))

input_df = pd.DataFrame({
    'pclass': [testing_pclass], 
    'age': [testing_age],
    'sex': [testing_sex],
    'family_size': [testing_family_size],
})

testing_sample = model.predict(input_df)


if testing_sample[0] == 0:
    print('\nPassanger did not survive')
else:
    print('\nPassanger survived')
# Out:
# Passanger pclass: 1
# Passanger age: 23
# Passanger sex: female
# Passanger family_size: 2
#
# Passanger survived
# C:\Users\kmk\anaconda3\envs\AI\lib\site-packages\xgboost\data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):

# %% [markdown]
# ##  10. Conclusion

# %% [markdown]
# Working 21 hours for 2 weeks as a data scientist I have developed classification models that could predict survival rate among Titanic passengers predicted by the research factors.
# - First, I used different analysing techniques to see the relationship between features to the target. Some of the outputs from the analysis needed fact-checking, so I compared my findings to the real facts from the external resources.
# - Second, I extracted new data to see some patterns in the feature engineering part through merging variables and creating new factors.
# - Third, in this work, I put my efforts to visualise all of my findings in the 'EDA' and 'Feature Engineering' parts.
# - Fourth, I used pipelines and grid search to tune models' hyperparameters and find the best estimators for them.
# - Fifth, I added five different types of classification metrics and also used a confusion matrix to visualise models predicting errors.
# - Six, I separately built a testing sample where you could type information about passengers and forecast whether he/she would survive or not.
#
# In this classification task I used XGBClassifier, RandomForestClassifier, Decision Tree Classifier, Gradient Boosting Classifier, SVC, LogisticRegression, AdaBoost Classifier and KNeighbors Classifier. XGBClassifier and RandomForestClassifier showed better scores in accuracy compared with other models. I also added a description about each hyperparameter that I tuned. In the pipeline, I added imputation methods, encoding methods, scaling methods (for some) and additionally added functions to drop constant, duplicated and correlated features (though, eventually I ended up keeping only a few factors, I decided not to delete and keep these functions).
#
# I hope that my work will help you and perhaps answer some of your questions. I tried to comment on each line of the code, describe all graphs and even add some comments after each analytical and feature engineering part for your convenience. Please like and leave a comment if you liked my work. And I wish each and everyone of you [Happy Coding].
#
# --------------------------------------------------------------------------------------------------Thank you!-------------------------------------------------------------------------------------------------
